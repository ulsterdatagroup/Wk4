# %%
x = [3,2,1]

# %%
x.sort()

# %%
print(x)
# Out:
# [1, 2, 3]

# %%
file = open('CSV-Example.csv', 'r')
lines = file.readlines()
file.close()
# Out:
# ['module_name,module_code\n', 'Data Science Foundations,COM738\n', 'Business Intelligence,COM735\n', 'Database and Cloud Computing,COM739\n', 'Masters Project,COM865']

# %%
file = open('CSV-Example.csv', 'r')
for line in file:
    print(line)
file.close()
# Out:
# module_name,module_code
#
# Data Science Foundations,COM738
#
# Business Intelligence,COM735
#
# Database and Cloud Computing,COM739
#
# Masters Project,COM865

# %%
file = open('CSV-Example.csv', 'r')
for line in file:
    words = line.split(' ')
    print("{0} words in: {1}".format(len(words),line))
file.close()
# Out:
# 1 words in: module_name,module_code
#
# 3 words in: Data Science Foundations,COM738
#
# 2 words in: Business Intelligence,COM735
#
# 4 words in: Database and Cloud Computing,COM739
#
# 2 words in: Masters Project,COM865

# %%
import math
print(math.sqrt(36))
# Out:
# 6.0

# %%
import math as m
print(m.sqrt(36))
# Out:
# 6.0

# %%
import csv
with open('CSV-Example.csv') as csvfile:
    readcsv = csv.reader(csvfile, delimiter=',')
    for row in readcsv:
        print("Full row: ",row)
        print("Row[0]: ",row[0])
        print("Row[1]: ",row[1])
# Out:
# Full row:  ['module_name', 'module_code']
# Row[0]:  module_name
# Row[1]:  module_code
# Full row:  ['Data Science Foundations', 'COM738']
# Row[0]:  Data Science Foundations
# Row[1]:  COM738
# Full row:  ['Business Intelligence', 'COM735']
# Row[0]:  Business Intelligence
# Row[1]:  COM735
# Full row:  ['Database and Cloud Computing', 'COM739']
# Row[0]:  Database and Cloud Computing
# Row[1]:  COM739
# Full row:  ['Masters Project', 'COM865']
# Row[0]:  Masters Project
# Row[1]:  COM865

# %%
import csv
with open('foodhygienedata.csv') as csvfile:
    reader = csv.DictReader(csvfile, delimiter=',')
    for row in reader:
        name = row["establishmentname"]
        print(name)
# Out:
# Heyn Group
# Rosemary Lunch Club
# John Ross & Co Auctioneers
# The Maverick/Boom Box
# Maverick
# Windsor Recreation & Social Cl
# The Chester Inn
# The Sportsman
# City Hibernians Club
# Forthriver Bowling & Tennis Club
# Shawsbridge Sports Association
# Muriels Cafe Bar
# MCGLONES
# The Corner House
# Ewarts Bowling Club
# Ligoniel Working Mens Club
# DUNMURRY INN
# McEnaney's
# LAUREL GLEN
# Linfield Football Club - Temporary Clubhouse
# DUNMURRY RECREATION & FOOTBALL CLUB
# McKennas
# Ardoyne Working Mens Club
# The Stadium Bar
# Ollies
# The Harp Bar
# Shorts Sports & Recreation Club
# The Spaniard
# The Bar with No Name
# Cliftonville Golf Club Catering
# Bootleggers
# Sunflower Public House
# Bittles Bar
# Harland & Wolff Staff Sports & Recreation Association
# Fountain Bar
# The Farmers
# The Poet
# Glentoran Football Club ( The Oval)
# Ballynafeigh Apprentice Boys Club
# Fitzgeralds
# Cavehill Inn
# North Belfast Orange Memorial Hall
# Sliabh Dubh Bar
# ...
